# %% [markdown]
# PART 1

# %%
import nltk
nltk.download('punkt')
import numpy as np
from collections import Counter
import itertools
from tqdm import tqdm_notebook as tqdm
import time

# %%
#Read the text into memory, tokenize the text into words
def tokenize(file_path):  
    data, lst = [], []
    with open(file_path, 'r') as f:  
        for line in f:
            if line== '\n':
                data.append(lst)
                lst = []
            else:
                lines = line.replace("\n",'').split(" ")
                lst.append(tuple(lines))
    return data

EN_train_sentences = tokenize('data/EN/train')
#print(EN_train_sentences)

# %%
def emission_parameter(data):
    
    tag_count = {}
    match_count = {}
    all_words, all_tags = [], []
    
    for lst in data:         
        for wordTuples in lst:
            
            tag = wordTuples[1]
            all_tags.append(tag)
            all_words.append(wordTuples[0])
            tag_count[tag] = tag_count.get(tag, 0) + 1
            match_count[wordTuples] = match_count.get(wordTuples, 0) + 1
            
      
    em = {i: np.log(match_count[i]/tag_count[i[1]]) for i in match_count}
    word_count = dict(Counter(all_words))
    all_words, all_tags = list(set(all_words)), list(set(all_tags))
    for p in range(len(all_words)):
        for q in range(len(all_tags)):       
            if (all_words[p], all_tags[q]) not in em:
                em[(all_words[p], all_tags[q])] = -2**31
    
    return word_count, tag_count, em, match_count, all_tags
  
EN_train_word_count, EN_train_tag_count, EN_train_emission, EN_emission_count, EN_all_tags = emission_parameter(EN_train_sentences)

print(EN_all_tags)
print(EN_train_word_count)
print(EN_train_tag_count)
print(EN_train_emission)
print(EN_emission_count)
# Out:
# ['O', 'I-negative', 'B-positive', 'I-positive', 'B-neutral', 'B-negative', 'I-neutral']
# {'All': 3, 'in': 267, 'all': 78, ',': 965, 'the': 1132, 'food': 259, 'was': 444, 'great': 152, '(': 87, 'except': 4, 'for': 287, 'dessserts': 1, ')': 92, '.': 1508, 'I': 485, 'have': 157, 'NEVER': 5, 'been': 53, 'disappointed': 13, 'Red': 2, 'Eye': 1, 'Great': 35, 'with': 155, 'an': 53, 'awesome': 7, 'atmosphere': 30, '!': 280, 'The': 312, 'sangria': 1, 'pretty': 16, 'tasty': 20, 'and': 775, 'good': 144, 'on': 160, 'a': 543, 'hot': 14, 'muggy': 1, 'day': 14, 'Also': 9, 'waiters': 9, 'try': 36, 'to': 504, 'push': 1, 'more': 43, 'you': 196, 'like': 69, 'suggest': 2, 'things': 12, 'as': 66, 'if': 59, 'they': 75, 'are': 126, 'complimentary': 5, 'when': 43, 'actually': 12, 'cost': 4, '$': 46, 'restaurant': 115, 'is': 465, 'cute': 6, 'but': 183, 'not': 155, 'upscale': 1, 'Hey': 1, 'think': 18, '2': 15, '+': 5, '5': 10, 'block': 3, 'walk': 5, "ain't": 1, 'bad': 26, 'And': 14, 'evaluated': 1, 'those': 9, 'terms': 2, 'Pastis': 1, 'simply': 10, 'wonderful': 11, 'recieved': 1, 'prompt': 8, 'service': 137, 'smile': 2, 'menu': 40, 'looked': 6, 'waiter': 18, 'very': 107, 'nice': 35, 'came': 29, 'it': 237, 'average': 19, 'look': 9, 'forward': 2, 'eating': 11, 'here': 79, 'again': 24, 'entire': 3, 'staff': 44, 'extremely': 9, 'accomodating': 3, 'tended': 1, 'my': 129, 'every': 22, 'need': 10, 'luke': 1, 'warm': 7, 'Excellent': 7, 'although': 8, 'interior': 3, 'could': 19, 'use': 4, 'some': 37, 'help': 4, 'It': 37, 'one': 66, 'of': 338, 'few': 15, 'places': 22, 'SoCal': 2, 'where': 12, 'would': 59, 'around': 19, 'take': 20, 'car': 1, 'Everything': 9, 'we': 136, 'had': 123, 'or': 69, 'ok': 12, '...': 99, 'definitely': 11, 'nothing': 21, 'Dinners': 1, 'always': 40, 'excellent': 31, 'quality': 15, 'dinner': 34, 'only': 41, 'took': 16, 'us': 41, 'about': 63, 'hour': 8, 'prices': 27, 'were': 133, 'alright': 3, 'strip': 2, 'almost': 8, '50': 2, '/': 16, 'pp': 2, 'after': 17, 'tax': 1, 'tip': 5, 'We': 79, 'went': 31, '9:30': 1, 'Friday': 3, 'died': 2, 'down': 18, 'bit': 20, 'by': 66, 'then': 14, 'so': 109, 'Ive': 4, 'many': 27, 'Thai': 18, 'restaurants': 31, 'Manhattan': 7, 'before': 16, 'Toons': 4, 'far': 14, 'best': 57, "mom's": 1, 'course': 8, 'Have': 4, 'frequented': 1, "'": 19, 'ino': 1, 'several': 10, 'years': 19, 'remains': 1, 'Run': 1, "don't": 38, 'nearly': 2, 'impossible': 1, 'get': 56, 'table': 30, 'ever': 20, 'chance': 3, 'go': 78, 'DO': 3, 'NOT': 6, 'pass': 3, 'up': 33, 'This': 57, 'place': 174, 'must': 17, 'owners': 4, 'afortune': 1, 'build': 1, "It's": 20, 'somewhere': 5, 'can': 54, 'eat': 33, 'be': 104, 'happy': 8, '-': 85, 'little': 28, 'expensive': 15, 'side': 16, 'fresh': 28, 'On': 3, 'weekends': 3, 'might': 9, 'wait': 39, 'couple': 8, 'hours': 5, 'Add': 1, 'that': 168, 'at': 125, 'reasonable': 7, 'price': 25, 'yourself': 6, 'beginning': 1, 'evening': 13, '–': 56, 'summertime': 1, 'deck': 1, 'experience--they': 1, 'will': 42, 'even': 30, 'bring': 2, 'blanket': 1, 'cold': 6, 'Seattle': 8, 'weather': 4, 'What': 10, 'Service': 22, 'friendliest': 2, 'our': 59, '"': 49, 'large': 12, 'party': 10, "pepperoni's": 1, 'cut': 3, 'real': 7, 'thick--Yum': 1, 'never': 37, 'cheescake': 1, 'this': 160, 'Our': 10, 'server': 9, 'helpful': 5, 'friendly': 31, 'THe': 3, 'Pizza': 12, 'wine': 32, 'excellent-the': 1, 'too--but': 1, 'what': 41, 'really': 47, 'MADE': 1, 'backyard': 2, 'dining': 15, 'area': 12, 'mussels': 2, 'fantastic': 17, 'dessert': 14, 'going': 23, 'back': 58, 'soon': 3, 'thing': 21, 'also': 20, 'quite': 14, 'terrific': 4, 'homemade': 5, 'pasta': 5, 'got': 25, 'shellfish': 1, 'shrimp': 8, 'appetizer': 13, "I'll": 7, 'keep': 8, 'short': 3, 'They': 20, 'rolls': 15, 'triple': 1, 'color': 1, 'norwegetan': 1, 'filling': 2, 'Why': 1, '?': 30, 'First': 4, 'am': 21, 'from': 55, 'Long': 2, 'Beach': 3, 'If': 23, 'delivered': 3, "they'd": 1, 'make': 35, 'mint': 2, 'As': 12, 'part': 10, 'small': 18, 'four': 7, 'dropped': 3, 'off': 18, 'without': 13, 'comment': 5, ';': 16, 'enjoy': 19, 'simplicity': 1, 'decor': 23, 'intimate': 5, 'feeling': 6, 'A': 3 ...
 'O'): 4, ('frequented', 'O'): 1, ("'", 'O'): 18, ('ino', 'O'): 1, ('several', 'O'): 10, ('years', 'O'): 19, ('remains', 'O'): 1, ('Run', 'O'): 1, ("don't", 'O'): 38, ('nearly', 'O'): 2, ('impossible', 'O'): 1, ('get', 'O'): 56, ('table', 'O'): 28, ('ever', 'O'): 20, ('chance', 'O'): 3, ('go', 'O'): 78, ('DO', 'O'): 3, ('NOT', 'O'): 6, ('pass', 'O'): 3, ('up', 'O'): 33, ('This', 'O'): 57, ('place', 'O'): 70,  ...

# %%
# Create a dictionary f, inside which we store the following key-value mappings:
# str(x, y)) -> log e(x|y)
def emission_parameter_string_key(data):
    ret = {}
    for k, v in data.items():
        ret['emission:'+ k[1]+ '+'+ k[0]] = v
    return ret

EN_emission_pairs = emission_parameter_string_key(EN_train_emission)
print(EN_emission_pairs)
# Out:
# {'emission:O+All': -9.017685611042436, 'emission:O+in': -4.54034879656423, 'emission:O+all': -5.785564559424215, 'emission:O+,': -3.24728344904484, 'emission:O+the': -3.0916488692569097, 'emission:B-positive+food': -2.2107041411644595, 'emission:O+was': -4.020473337278322, 'emission:O+great': -5.09241737886427, 'emission:O+(': -5.759589073020955, 'emission:O+except': -8.730003538590656, 'emission:O+for': -4.46732366154934, 'emission:B-negative+dessserts': -5.934894195619588, 'emission:O+)': -5.685481100867233, 'emission:O+.': -2.797758351142645, 'emission:O+I': -3.932149008773063, 'emission:O+have': -5.060052094362239, 'emission:O+NEVER': -8.506859987276446, 'emission:O+been': -6.146005986158425, 'emission:O+disappointed': -7.55134854224901, 'emission:B-positive+Red': -6.392754283805666, 'emission:I-positive+Eye': -6.3561076606958915, 'emission:O+Great': -6.560949838221132, 'emission:O+with': -5.13269127800221, 'emission:O+an': -6.146005986158425, 'emission:O+awesome': -8.170387750655234, 'emission:B-positive+atmosphere': -4.09016919081162, 'emission:O+!': -4.481508296541297, 'emission:O+The': -4.382956622812801, 'emission:B-positive+sangria': -7.0859014643656115, 'emission:O+pretty': -7.343709177470765, 'emission:O+tasty': -7.120565626156555, 'emission:O+and': -3.4975589161933267, 'emission:O+good': -5.153453269450639, 'emission:O+on': -5.0728727827913, 'emission:O+a': -3.822878620864065, 'emission:O+hot': -7.919073322374327, 'emission:O+muggy': -10.116297899710545, 'emission:O+day': -7.4772405700952875, 'emission:O+Also': -7.919073322374327, 'emission:B-negative+waiters': -5.241747015059643, 'emission:O+try': -6.5327789612544365, 'emission:O+to': -3.895707729610807, 'emission:O+push': -10.116297899710545, 'emission:O+more': -6.3550977840169836, 'emission:O+food': -6.146005986158425, 'emission:O+you': -4.848439740647218, 'emission:O+like': -5.882191395113287, 'emission:O+suggest': -9.4231507191506, 'emission:O+things': -7.6313912499225465, 'emission:O+as': -5.926643157684121, 'emission:O+if': -6.038760455804827, 'emission:O+they': -5.798809786174236, 'emission:O+are': -5.280015992759068, 'emission:O+complimentary': -8.506859987276446, 'emission:O+when': -6.3550977840169836, 'emission:O+actually': -7.6313912499225465, 'emission:O+cost': -8.730003538590656, 'emission:O+$': -6.287656503221451, 'emission:B-neutral+restaurant': -3.6506582412937383, 'emission:O+is': -3.97426049412319, 'emission:O+cute': -8.324538430482491, 'emission:O+but': -4.906811746869125, 'emission:O+not': -5.0728727827913, 'emission:O+upscale': -10.116297899710545, 'emission:O+Hey': -10.116297899710545, 'emission:O+think': -7.225926141814382, 'emission:O+2': -7.408247698608337, 'emission:O++': -8.730003538590656, 'emission:O+5': -7.8137128067165005, 'emission:O+block': -9.4231507191506, 'emission:O+walk': -8.506859987276446, "emission:O+ain't": -10.116297899710545, 'emission:O+bad': -6.858201361689065, 'emission:O+And': -7.4772405700952875, 'emission:O+evaluated': -10.116297899710545, 'emission:O+those': -7.919073322374327, 'emission:O+terms': -9.4231507191506, 'emission:B-positive+Pastis': -7.0859014643656115, 'emission:O+simply': -7.8137128067165005, 'emission:O+wonderful': -7.718402626912176, 'emission:O+recieved': -10.116297899710545, 'emission:O+prompt': -8.036856358030711, 'emission:B-positive+service': -2.7038748296917294, 'emission:O+smile': -9.4231507191506, 'emission:B-positive+menu': -5.006459922685775, 'emission:O+looked': -8.324538430482491, 'emission:B-positive+waiter': -5.294141995137556, 'emission:O+very': -5.443469065248641, 'emission:O+nice': -6.560949838221132, 'emission:B-neutral+food': -1.8588987720656835, 'emission:O+came': -6.749002069724073, 'emission:O+it': -4.648237758575415, 'emission:O+average': -7.171858920544106, 'emission:O+look': -7.919073322374327, 'emission:O+forward': -9.4231507191506, 'emission:O+eating': -7.718402626912176, 'emission:O+here': -5.746850047243525, 'emission:O+again': -6.938244069362601, 'emission:O+entire':  ...

# %% [markdown]
# PART 1 (ii)

# %%
def transition_parameter(data):
    tag_transition_count={} # (tag0,tag1):count
    
    tag_count = {} # tag0:count
    all_tags = []
    print(len(data))
    flag = 0
    
    for sent in data:
        idx = data.index(sent)
        
        for i in range(len(sent)):
            tag0 = sent[i-1][1] if i != 0 else 'START'
            tag1 = sent[i][1]
            tag_count[tag0]=tag_count.get(tag0,0) + 1
            tag_transition=(tag0,tag1)
            all_tags.append(tag0)
            tag_transition_count[tag_transition] = tag_transition_count.get(tag_transition,0)+1

        tag0 = sent[-1][1]
        tag1 = "STOP"
        tag_count[tag0]=tag_count.get(tag0,0) + 1
        tag_transition=(tag0,tag1)
        all_tags.append(tag0)
        tag_transition_count[tag_transition] = tag_transition_count.get(tag_transition,0)+1
                
    transition_parameter = {k: np.log(tag_transition_count[k]/tag_count[k[0]])
                        for k in tag_transition_count}
    
    all_tags = list(set(all_tags)) + ['STOP']
    print(all_tags)
    for p in range(len(all_tags)):
        for q in range(len(all_tags)):
            if (all_tags[p], all_tags[q]) not in transition_parameter:
                transition_parameter[(all_tags[p], all_tags[q])] = -2**31
    print(tag_count)
    
    return transition_parameter, tag_transition_count

EN_train_transition, EN_transition_count = transition_parameter(EN_train_sentences)
print(EN_train_transition)
print(EN_transition_count)
# Out:
# 1873
# ['O', 'I-negative', 'B-positive', 'I-positive', 'START', 'B-neutral', 'B-negative', 'I-neutral', 'STOP']
# {'START': 1873, 'O': 24743, 'B-positive': 1195, 'B-negative': 378, 'I-positive': 576, 'B-neutral': 77, 'I-neutral': 25, 'I-negative': 127}
# 2065
# ['O', 'B-conflict', 'I-negative', 'B-positive', 'I-positive', 'START', 'B-neutral', 'B-negative', 'I-neutral', 'STOP']
# {'START': 2065, 'O': 32234, 'B-negative': 436, 'I-negative': 227, 'B-positive': 1288, 'B-neutral': 86, 'I-positive': 406, 'I-neutral': 23, 'B-conflict': 1}
# {('START', 'O'): -0.06165959394788234, ('O', 'O'): -0.1469289780609056, ('O', 'B-positive'): -3.100585479223317, ('B-positive', 'O'): -0.3572728512809094, ('O', 'B-negative'): -4.235764913309846, ('B-negative', 'O'): -0.2344506222289012, ('O', 'STOP'): -2.5966054955940074, ('B-positive', 'I-positive'): -1.2540189870820944, ('I-positive', 'O'): -0.5419771288708248, ('O', 'B-neutral'): -5.94191062981491, ('B-neutral', 'O'): -0.23293155768037255, ('START', 'B-negative'): -4.539564428890097, ('START', 'B-positive'): -3.153270067770207, ('I-positive', 'I-positive'): -0.8965221465517323, ('B-neutral', 'I-neutral'): -1.7788560643921472, ('I-neutral', 'I-neutral'): -0.7339691750802004, ('I-neutral', 'O'): -0.6539264674066639, ('B-negative', 'I-negative'): -1.6041608553332567, ('I-negative', 'O'): -0.5134537461722601, ('START', 'B-neutral'): -5.0503900526560885, ('I-negative', 'I-negative'): -0.9123614537342655, ('B-positive', 'STOP'): -4.252688120309395, ('I-positive', 'STOP'): -4.564348191467836, ('B-positive', 'B-positive'): -7.0859014643656115, ('B-neutral', 'STOP'): -3.245193133185574, ('B-negative', 'STOP'): -4.836281906951478, ('O', 'I-negative'): -2147483648, ('O', 'I-positive'): -2147483648, ('O', 'START'): -2147483648, ('O', 'I-neutral'): -2147483648, ('I-negative', 'B-positive'): -2147483648, ('I-negative', 'I-positive'): -2147483648, ('I-negative', 'START'): -2147483648, ('I-negative', 'B-neutral'): -2147483648, ('I-negative', 'B-negative'): -2147483648, ('I-negative', 'I-neutral'): -2147483648, ('I-negative', 'STOP'): -2147483648, ('B-positive', 'I-negative'): -2147483648, ('B-positive', 'START'): -2147483648, ('B-positive', 'B-neutral'): -2147483648, ('B-positive', 'B-negative'): -2147483648, ('B-positive', 'I-neutral'): -2147483648, ('I-positive', 'I-negative'): -2147483648, ('I-positive', 'B-positive'): -2147483648, ('I-positive', 'START'): -2147483648, ('I-positive', 'B-neutral'): -2147483648, ('I-positive', 'B-negative'): -2147483648, ('I-positive', 'I-neutral'): -2147483648, ('START', 'I-negative'): -2147483648, ('START', 'I-positive'): -2147483648, ('START', 'START'): -2147483648, ('START', 'I-neutral'): -2147483648, ('START', 'STOP'): -2147483648, ('B-neutral', 'I-negative'): -2147483648, ('B-neutral', 'B-positive'): -2147483648, ('B-neutral', 'I-positive'): -2147483648, ('B-neutral', 'START'): -2147483648, ('B-neutral', 'B-neutral'): -2147483648, ('B-neutral', 'B-negative'): -2147483648, ('B-negative', 'B-positive'): -2147483648, ('B-negative', 'I-positive'): -2147483648, ('B-negative', 'START'): -2147483648, ('B-negative', 'B-neutral'): -2147483648, ('B-negative', 'B-negative'): -2147483648, ('B-negative', 'I-neutral'): -2147483648, ('I-neutral', 'I-negative'): -2147483648, ('I-neutral', 'B-positive'): -2147483648, ('I-neutral', 'I-positive'): -2147483648, ('I-neutral', 'START'): -2147483648, ('I-neutral', 'B-neutral'): -2147483648, ('I-neutral', 'B-negative'): -2147483648, ('I-neutral', 'STOP'): -2147483648, ('STOP', 'O'): -2147483648, ('STOP', 'I-negative'): -2147483648, ('STOP', 'B-positive'): -2147483648, ('STOP', 'I-positive'): -2147483648, ('STOP', 'START'): -2147483648, ('STOP', 'B-neutral'): -2147483648, ('STOP', 'B-negative'): -2147483648, ('STOP', 'I-neutral'): -2147483648, ('STOP', 'STOP'): -2147483648}
# {('START', 'O'): 1761, ('O', 'O'): 21362, ('O', 'B-positive'): 1114, ('B-positive', 'O'): 836, ('O', 'B-negative'): 358, ('B-negative', 'O'): 299, ('O', 'STOP'): 1844, ('B-positive', 'I-positive'): 341, ('I-positive', 'O'): 335, ('O', 'B-neutral'): 65, ('B-neutral', 'O'): 61, ('START', 'B-negative'): 20, ('START', 'B-positive'): 80, ('I-positive', 'I-positive'): 235, ('B-neutral', 'I-neutral'): 13, ('I-neutral', 'I-neutral'): 12, ('I-neutral', 'O'): 13, ('B-negative', 'I-negative'): 76, ('I-negative', 'O'): 76, ('START', 'B-neutral'): 12, ('I-negative', 'I-negative'): 51, ('B-positive', 'STOP'): 17, ('I-positive', 'STOP'): 6, ('B-positive', 'B-positive'): 1, ('B-neutral', 'STOP'): 3, ('B-negative', 'STOP'): 3}

# %%
def transition_parameter_string_key(data):
    ret = {}
    for k, v in data.items():
        ret['transition:'+ k[0]+ '+'+ k[1]] = v
    return ret

EN_transition_pairs = transition_parameter_string_key(EN_train_transition)
print(EN_transition_pairs)
# Out:
# {'transition:START+O': -0.06165959394788234, 'transition:O+O': -0.1469289780609056, 'transition:O+B-positive': -3.100585479223317, 'transition:B-positive+O': -0.3572728512809094, 'transition:O+B-negative': -4.235764913309846, 'transition:B-negative+O': -0.2344506222289012, 'transition:O+STOP': -2.5966054955940074, 'transition:B-positive+I-positive': -1.2540189870820944, 'transition:I-positive+O': -0.5419771288708248, 'transition:O+B-neutral': -5.94191062981491, 'transition:B-neutral+O': -0.23293155768037255, 'transition:START+B-negative': -4.539564428890097, 'transition:START+B-positive': -3.153270067770207, 'transition:I-positive+I-positive': -0.8965221465517323, 'transition:B-neutral+I-neutral': -1.7788560643921472, 'transition:I-neutral+I-neutral': -0.7339691750802004, 'transition:I-neutral+O': -0.6539264674066639, 'transition:B-negative+I-negative': -1.6041608553332567, 'transition:I-negative+O': -0.5134537461722601, 'transition:START+B-neutral': -5.0503900526560885, 'transition:I-negative+I-negative': -0.9123614537342655, 'transition:B-positive+STOP': -4.252688120309395, 'transition:I-positive+STOP': -4.564348191467836, 'transition:B-positive+B-positive': -7.0859014643656115, 'transition:B-neutral+STOP': -3.245193133185574, 'transition:B-negative+STOP': -4.836281906951478, 'transition:O+I-negative': -2147483648, 'transition:O+I-positive': -2147483648, 'transition:O+START': -2147483648, 'transition:O+I-neutral': -2147483648, 'transition:I-negative+B-positive': -2147483648, 'transition:I-negative+I-positive': -2147483648, 'transition:I-negative+START': -2147483648, 'transition:I-negative+B-neutral': -2147483648, 'transition:I-negative+B-negative': -2147483648, 'transition:I-negative+I-neutral': -2147483648, 'transition:I-negative+STOP': -2147483648, 'transition:B-positive+I-negative': -2147483648, 'transition:B-positive+START': -2147483648, 'transition:B-positive+B-neutral': -2147483648, 'transition:B-positive+B-negative': -2147483648, 'transition:B-positive+I-neutral': -2147483648, 'transition:I-positive+I-negative': -2147483648, 'transition:I-positive+B-positive': -2147483648, 'transition:I-positive+START': -2147483648, 'transition:I-positive+B-neutral': -2147483648, 'transition:I-positive+B-negative': -2147483648, 'transition:I-positive+I-neutral': -2147483648, 'transition:START+I-negative': -2147483648, 'transition:START+I-positive': -2147483648, 'transition:START+START': -2147483648, 'transition:START+I-neutral': -2147483648, 'transition:START+STOP': -2147483648, 'transition:B-neutral+I-negative': -2147483648, 'transition:B-neutral+B-positive': -2147483648, 'transition:B-neutral+I-positive': -2147483648, 'transition:B-neutral+START': -2147483648, 'transition:B-neutral+B-neutral': -2147483648, 'transition:B-neutral+B-negative': -2147483648, 'transition:B-negative+B-positive': -2147483648, 'transition:B-negative+I-positive': -2147483648, 'transition:B-negative+START': -2147483648, 'transition:B-negative+B-neutral': -2147483648, 'transition:B-negative+B-negative': -2147483648, 'transition:B-negative+I-neutral': -2147483648, 'transition:I-neutral+I-negative': -2147483648, 'transition:I-neutral+B-positive': -2147483648, 'transition:I-neutral+I-positive': -2147483648, 'transition:I-neutral+START': -2147483648, 'transition:I-neutral+B-neutral': -2147483648, 'transition:I-neutral+B-negative': -2147483648, 'transition:I-neutral+STOP': -2147483648, 'transition:STOP+O': -2147483648, 'transition:STOP+I-negative': -2147483648, 'transition:STOP+B-positive': -2147483648, 'transition:STOP+I-positive': -2147483648, 'transition:STOP+START': -2147483648, 'transition:STOP+B-neutral': -2147483648, 'transition:STOP+B-negative': -2147483648, 'transition:STOP+I-neutral': -2147483648, 'transition:STOP+STOP': -2147483648}

# %% [markdown]
# PART 2 (i)

# %%
def calculate_score(sentence, emission, transition):
    wf = 0
    x_seq = [x[0] for x in sentence]
    y_seq = ['START']+[y[1] for y in sentence]+['STOP']
    
    for i in range(len(x_seq)):
        key = (x_seq[i], y_seq[i+1])
        wf+= emission[key]
    for j in range(1, len(y_seq)):
        key = (y_seq[j-1], y_seq[j])
        wf+= transition[key]
        
    return wf
calculate_score(EN_train_sentences[0], EN_train_emission, EN_train_transition)
# Out:
# -85.52845366888087

# %% [markdown]
# PART 2 (ii)

# %%
def viterbi(sentence, tags, trans, emit):    
    pi = [{}]
    path = {}
    
    # j = 0 (START)
    for tag in tags:
        pi[0][tag] = trans.get(('START',tag),0) + emit.get((sentence[0][0],tag),0)
        path[tag] = [tag]

    # j = 1 ~ N-1
    for t in range(1,len(sentence)):
        pi.append({})
        newpath = {}

        for y in tags:
            (prob, tag) = max([(pi[t-1][y0] + trans.get((y0,y),0) + emit.get((sentence[t][0],y),0), y0) 
                               for y0 in tags])
            pi[t][y] = prob
            newpath[y] = path[tag] + [y]

        #print(newpath)
        path = newpath
        
    # j = N+1 (STOP)
    (prob, tag) = max([(pi[len(sentence)-1][y] + trans.get((y,'STOP'),0), y) for y in tags])
    
    return prob, path[tag]

def write_prediction(output_filename, test_data, tags, emit, trans):
    
    with open(output_filename, "w") as outfile:
        for sentence in test_data:
            
            # generate tag sequence
            predicted_tag_sequence = viterbi(sentence, tags, trans, emit)[1]
            
            # handle inconsistent length
            if len(sentence) != len(predicted_tag_sequence):
                print("WARNING!! Different length {} / {}".format(sentence, predicted_tag_sequence))
            
            # write to file
            for i in range(len(sentence)):
                line = "{} {}\n".format(sentence[i][0], predicted_tag_sequence[i])
                outfile.write(line)
                
            outfile.write("\n")

# %%
EN_dev_sentences = tokenize('data/EN/dev.in')
print(EN_train_emission)

write_prediction('data/EN/dev.p2.out', EN_dev_sentences,
                 EN_all_tags, EN_train_emission, EN_train_transition)
# Out:
# {('All', 'O'): -9.017685611042436, ('in', 'O'): -4.54034879656423, ('all', 'O'): -5.785564559424215, (',', 'O'): -3.24728344904484, ('the', 'O'): -3.0916488692569097, ('food', 'B-positive'): -2.2107041411644595, ('was', 'O'): -4.020473337278322, ('great', 'O'): -5.09241737886427, ('(', 'O'): -5.759589073020955, ('except', 'O'): -8.730003538590656, ('for', 'O'): -4.46732366154934, ('dessserts', 'B-negative'): -5.934894195619588, (')', 'O'): -5.685481100867233, ('.', 'O'): -2.797758351142645, ('I', 'O'): -3.932149008773063, ('have', 'O'): -5.060052094362239, ('NEVER', 'O'): -8.506859987276446, ('been', 'O'): -6.146005986158425, ('disappointed', 'O'): -7.55134854224901, ('Red', 'B-positive'): -6.392754283805666, ('Eye', 'I-positive'): -6.3561076606958915, ('Great', 'O'): -6.560949838221132, ('with', 'O'): -5.13269127800221, ('an', 'O'): -6.146005986158425, ('awesome', 'O'): -8.170387750655234, ('atmosphere', 'B-positive'): -4.09016919081162, ('!', 'O'): -4.481508296541297, ('The', 'O'): -4.382956622812801, ('sangria', 'B-positive'): -7.0859014643656115, ('pretty', 'O'): -7.343709177470765, ('tasty', 'O'): -7.120565626156555, ('and', 'O'): -3.4975589161933267, ('good', 'O'): -5.153453269450639, ('on', 'O'): -5.0728727827913, ('a', 'O'): -3.822878620864065, ('hot', 'O'): -7.919073322374327, ('muggy', 'O'): -10.116297899710545, ('day', 'O'): -7.4772405700952875, ('Also', 'O'): -7.919073322374327, ('waiters', 'B-negative'): -5.241747015059643, ('try', 'O'): -6.5327789612544365, ('to', 'O'): -3.895707729610807, ('push', 'O'): -10.116297899710545, ('more', 'O'): -6.3550977840169836, ('food', 'O'): -6.146005986158425, ('you', 'O'): -4.848439740647218, ('like', 'O'): -5.882191395113287, ('suggest', 'O'): -9.4231507191506, ('things', 'O'): -7.6313912499225465, ('as', 'O'): -5.926643157684121, ('if', 'O'): -6.038760455804827, ('they', 'O'): -5.798809786174236, ('are', 'O'): -5.280015992759068, ('complimentary', 'O'): -8.506859987276446, ('when', 'O'): -6.3550977840169836, ('actually', 'O'): -7.6313912499225465, ('cost', 'O'): -8.730003538590656, ('$', 'O'): -6.287656503221451, ('restaurant', 'B-neutral'): -3.6506582412937383, ('is', 'O'): -3.97426049412319, ('cute', 'O'): -8.324538430482491, ('but', 'O'): -4.906811746869125, ('not', 'O'): -5.0728727827913, ('upscale', 'O'): -10.116297899710545, ('Hey', 'O'): -10.116297899710545, ('think', 'O'): -7.225926141814382, ('2', 'O'): -7.408247698608337, ('+', 'O'): -8.730003538590656, ('5', 'O'): -7.8137128067165005, ('block', 'O'): -9.4231507191506, ('walk', 'O'): -8.506859987276446, ("ain't", 'O'): -10.116297899710545, ('bad', 'O'): -6.858201361689065, ('And', 'O'): -7.4772405700952875, ('evaluated', 'O'): -10.116297899710545, ('those', 'O'): -7.919073322374327, ('terms', 'O'): -9.4231507191506, ('Pastis', 'B-positive'): -7.0859014643656115, ('simply', 'O'): -7.8137128067165005, ('wonderful', 'O'): -7.718402626912176, ('recieved', 'O'): -10.116297899710545, ('prompt', 'O'): -8.036856358030711, ('service', 'B-positive'): -2.7038748296917294, ('smile', 'O'): -9.4231507191506, ('menu', 'B-positive'): -5.006459922685775, ('looked', 'O'): -8.324538430482491, ('waiter', 'B-positive'): -5.294141995137556, ('very', 'O'): -5.443469065248641, ('nice', 'O'): -6.560949838221132, ('food', 'B-neutral'): -1.8588987720656835, ('came', 'O'): -6.749002069724073, ('it', 'O'): -4.648237758575415, ('average', 'O'): -7.171858920544106, ('look', 'O'): -7.919073322374327, ('forward', 'O'): -9.4231507191506, ('eating', 'O'): -7.718402626912176, ('here', 'O'): -5.746850047243525, ('again', 'O'): -6.938244069362601, ('entire', 'O'): -9.017685611042436, ('staff', 'B-positive'): -3.9504072484364614, ('extremely', 'O'): -7.919073322374327, ('accomodating', 'O'): -9.017685611042436, ('tended', 'O'): -10.116297899710545, ('my', 'O'): -5.256485495348874, ('every', 'O'): -7.02525544635223, ('need', 'O'): -7.8137128067165005, ('food', 'B-negative'): -2.323976282975363, ('luke', 'O'): -10.116297899710545, ('warm', 'O'): -8.1703877 ...

# %% [markdown]
# PART 3 (i)

# %%
def logSumExp(ns):
    maxi = np.max(ns)
    ds = ns - maxi
    sumOfExp = np.exp(ds).sum()
    return maxi + np.log(sumOfExp)

def forward_algorithm(sentence, tags, trans, emit):    
    pi = [{}]
    
    # t = 1
    for y in tags:
        pi[0][y] = trans.get(('START',y),0) + emit.get((sentence[0][0], y), 0)

    # t = 2 ~ N
    for t in range(1,len(sentence)):
        pi.append({})

        for y in tags:
            log_alpha = []
            for y_prev in tags:
                log_alpha.append(pi[t-1][y_prev] + trans.get((y_prev,y),0) + emit.get((sentence[t][0],y),0))
            pi[t][y] = logSumExp(log_alpha)
            
    # t = N+1 (STOP)
    t = len(sentence)
    log_alpha = []
    for y in tags:
        log_alpha.append(pi[t-1][y] + trans.get((y,'STOP'),0))
    
    return pi, logSumExp(log_alpha)

#forward_algorithm(EN_train_sentences[0], EN_all_tags, EN_train_transition, EN_train_emission)

# %%
def loss_func(sentences, trans, emi, all_tags):
    loss = 0
    for sent in sentences:
        loss+= calculate_score(sent, emi, trans)
        _, update = forward_algorithm(sent, all_tags, trans, emi)
        loss-= update
    return (-1)*loss
loss_func(EN_train_sentences, EN_train_transition, EN_train_emission, EN_all_tags)
# Out:
# 2050.7405338353574

# %% [markdown]
# PART 3 (ii)

# %%
def backward_algorithm(sentence, tags, trans, emit):    
    pi = [{} for i in range(len(sentence))]
    
    # t = N
    for tag in tags:
        pi[len(sentence)-1][tag] = trans.get((tag,'STOP'),0)
        

    # t = N-1 ~ 1
    for t in reversed(range(0,len(sentence)-1)):
        for y in tags:
            log_beta = []
            for y_next in tags:
                log_beta.append(pi[t+1][y_next] + trans.get((y, y_next),0) + emit.get((sentence[t+1][0],y_next),0))
            pi[t][y] = logSumExp(log_beta)

    # t = 0 (START)
    log_beta = []
    for y in tags:
        log_beta.append(pi[0][y] + trans.get(('START',y),0) + emit.get((sentence[0][0],y),0))
    
    return pi, logSumExp(log_beta)

#backward_algorithm(EN_train_sentences[0], EN_all_tags, EN_train_transition, EN_train_emission)

# %%
def fwd_bkw(sentence, all_tags, trans, emit):
    fwd, p_fwd = forward_algorithm(sentence, all_tags, trans, emit)
    bkw, p_bkw = backward_algorithm(sentence, all_tags, trans, emit)
    
        
    feature_expectation = {} # {feature: expectation}
    # t = 1
    for y in all_tags:
        x = sentence[0][0]
        t_feature = ('START',y)
        
        # update transition features
        update = bkw[0][y] + trans[t_feature] + emit[(x,y)] - p_fwd     
        feature_expectation[t_feature] = feature_expectation.get(t_feature,0) + np.exp(update)
        
        # update emission features
        e_feature = (x,y)
        update = fwd[0][y] + bkw[0][y] - p_fwd
        feature_expectation[e_feature] = feature_expectation.get(e_feature,0) + np.exp(update)

        
    # t = 2 ~ N
    for t in range(1,len(sentence)):
        for y in all_tags:
            x = sentence[t][0]
            x_prev = sentence[t-1][0]
            
            # update emission features
            e_feature = (x,y)
            update = fwd[t][y] + bkw[t][y] - p_fwd            
            feature_expectation[e_feature] = feature_expectation.get(e_feature,0) + np.exp(update)
            
            for y_prev in all_tags:
                # update transition features
                t_feature = (y_prev,y)
                update = fwd[t-1][y_prev] + bkw[t][y] + trans[t_feature] + emit[(x,y)]- p_fwd
                feature_expectation[t_feature] = feature_expectation.get(t_feature,0) + np.exp(update)
                
    # t = N+1 (STOP)
    t = len(sentence)
    for y in all_tags:
        # update transition features
        t_feature = (y,'STOP')
        update = fwd[t-1][y] + trans[t_feature]- p_fwd
        feature_expectation[t_feature] = feature_expectation.get(t_feature,0) + np.exp(update)
        
    return feature_expectation
                
#fwd_bkw(EN_train_sentences[0], EN_all_tags, EN_train_transition, EN_train_emission)

# %%
def get_feat_exp(ES_train_sentences, all_tags, trans, emi):
    feat_exp = {}
    for key in trans:
        feat_exp[key] = 0
    for key in emi:
        feat_exp[key] = 0

    for sent in ES_train_sentences:
        expect = fwd_bkw(sent, all_tags, trans, emi)
        for k,v in expect.items():
            
            feat_exp[k] += v
    return feat_exp
  
#print(get_feat_exp(EN_train_sentences, EN_all_tags, EN_train_transition, EN_train_emission))

# %%
def mapping(emission, transition):
    index_mapping = {}
    i = 0
    for em in emission:
        index_mapping[i] = em
        i+= 1
    for tr in transition:
        index_mapping[i] = tr
        i+= 1
        
    return index_mapping

index_mapping = mapping(EN_train_emission, EN_train_transition)

# %%
#feat_exp : []
def compute_grad(feat_exp, all_tags, trans, emi):
    grad_lst= [0 for i in range(len(index_mapping))]
    for i in range(len(feat_exp)):
        if index_mapping[i] in EN_emission_count:
            grad_lst[i] += (feat_exp[i]- EN_emission_count[index_mapping[i]])
        elif index_mapping[i] in EN_transition_count:
            grad_lst[i] += (feat_exp[i]- EN_transition_count[index_mapping[i]])
        else:
            grad_lst[i] += feat_exp[i]
    return grad_lst

#len(compute_grad(feat_exp, EN_all_tags, EN_train_sentences, EN_train_emission))

# %% [markdown]
# PART 4

# %%
def loss_with_reg(w, sentences, trans, emi, all_tags, n = 0.1):
    loss = loss_func(sentences, trans, emi, all_tags)
    # regularization
    loss += n*sum(w1*w1 for w1 in w)
    return loss

# %%
def grad_with_reg(feat_exp, w, trans, emi, all_tags, n = 0.1):
    grad_lst = compute_grad(feat_exp, all_tags, trans, emi)
    for i in range(len(w)):
        grad_lst[i] += w[i]*2*n
    return grad_lst

# %%
from scipy.optimize import fmin_l_bfgs_b
import time
total_start = time.time()

def callbackF(w):
    '''
    This function will be called by "fmin_l_bfgs_b"
    Arg:
    w: weights, numpy array
    '''
    loss = get_loss_grad(w)[0]
    print('Loss:{0:.4f}'.format(loss))
def get_loss_grad(w):
    '''
    This function will be called by "fmin_l_bfgs_b"
    Arg:
    w: weights, numpy array
    Returns:
    loss: loss, float
    grads: gradients, numpy array
    '''
    # to be completed by you
    start = time.time()
    emi, trans = {}, {}
    for i in range(len(list(index_mapping.keys()))): #27899
        if i< len(EN_train_emission): #27818
            emi[index_mapping[i]] = w[i]
        else:
            trans[index_mapping[i]] = w[i]
    
    feat_exp = get_feat_exp(EN_train_sentences, EN_all_tags, trans, emi)
    # change feat_exp to list
    ft = []
    for i in range(len(list(index_mapping.keys()))):
        ft.append(feat_exp[index_mapping[i]])
    
    loss = loss_with_reg(w, EN_train_sentences, trans, emi, EN_all_tags, n = 0.1)
    print('loss: '+ str(loss))
    
    grad_lst = grad_with_reg(ft, w, trans, emi, EN_all_tags, n = 0.1)
    #print('grad_lst: '+ str(grad_lst))
    grads = np.asarray(list(grad_lst)) 
    
    print(' time taken: '+ str(time.time()-start) +' total time: '+ str(time.time()-total_start))
    
    return loss, grads
  
  
init_w = np.asarray([0 for i in range(len(list(index_mapping.keys())))])
result = fmin_l_bfgs_b(get_loss_grad, init_w, pgtol=0.1)
# Out:
# loss: 52775.02915252912
#  time taken: 13.905869960784912 total time: 13.935021877288818
# loss: 31978.422560595383
#  time taken: 13.934737205505371 total time: 27.872556924819946
# loss: 19007.65777640145
#  time taken: 14.029085159301758 total time: 41.903762102127075
# loss: 15909.840926992101
#  time taken: 13.852178573608398 total time: 55.75893807411194
# loss: 24692.80562540524
#  time taken: 13.818942546844482 total time: 69.58005213737488
# loss: 12068.697074799862
#  time taken: 13.257317781448364 total time: 3592.996166944504
# loss: 3015.584463775417
#  time taken: 13.228461742401123 total time: 3606.2296357154846
# loss: 3015.5842742426194
#  time taken: 13.316112279891968 total time: 3619.5513639450073

# %%
emi, trans = {}, {}
for i in range(len(list(index_mapping.keys()))): #27899
    if i< len(EN_train_emission): #27818
        emi[index_mapping[i]] = result[0][i]
    else:
        trans[index_mapping[i]] = result[0][i]

write_prediction('data/EN/dev.p4.out', EN_dev_sentences,
                 EN_all_tags, emi, trans)

# %%
# !python evalResult.py data/EN/dev.out data/EN/dev.p2.out
# Out:
# #Entity in gold data: 210
# #Entity in prediction: 154
#
# #Correct Entity : 103
# Entity  precision: 0.6688
# Entity  recall: 0.4905
# Entity  F: 0.5659
#
# #Correct Sentiment : 71
# Sentiment  precision: 0.4610
# Sentiment  recall: 0.3381
# Sentiment  F: 0.3901

# %%
# !python evalResult.py data/EN/dev.out data/EN/dev.p4.out
# Out:
# #Entity in gold data: 210
# #Entity in prediction: 139
#
# #Correct Entity : 104
# Entity  precision: 0.7482
# Entity  recall: 0.4952
# Entity  F: 0.5960
#
# #Correct Sentiment : 73
# Sentiment  precision: 0.5252
# Sentiment  recall: 0.3476
# Sentiment  F: 0.4183

# %%
import pickle
f = open("EN_emi.pkl","wb")
pickle.dump(emi,f)
f.close()
f2 = open("EN_trans.pkl","wb")
pickle.dump(emi,f2)

#ff = open('EN_emi.pkl', 'rb')
#ee = pickle.load(ff)
#print(ee)

# %% [markdown]
# $\pi(0,y)=a_{START,y}+b_{y}(x_{0})$
#
# $\pi(t,y)=max_{yprev}\left\{\pi(t-1,yprev)+a_{yprev,y}+b_{y}(x_{t}) \right\}$
#
# $max_{y}\left\{\pi(n-1,y)+a_{y,STOP} \right\}$
#
# $\alpha_{y}(0)=a_{START,y}+b_{y}(x_{0})$
#
# $\alpha_{y}(t)=log(\sum_{y\_prev}\left\{exp(\alpha_{y\_prev}(t-1)+a_{y\_prev,y}+b_{y}(x_{t})) \right\})$
#
# $p\_fwd=log(\sum_{y}\left\{exp(\alpha_{y}(n-1)+a_{y,STOP})\right\})$
#
# $\beta_{y}(n-1)=a_{y,STOP}+b_{y}(x_{0})$
#
# $\beta_{y}(t)=log(\sum_{y\_next}\left\{exp(\beta_{y\_next}(t+1)+a_{y,y\_next}+b_{y\_next}(x_{t+1}) )\right\})$
#
# $p\_bkw=log(\sum_{y}\left\{exp(\beta_{y}(0)+a_{START,y} )\right\})$
#
# $E_{(x,y)} = exp(\alpha_{y}(0)+\beta_{y}(0)-p\_fwd)$
#
# $E_{(START,y)} =exp(\beta_{y}(0)+transition(START,y)+emission(x,y)-p\_fwd)$
#
# $E_{(x,y)} = E_{(x,y)}+exp(\alpha_{y}(t)+\beta_{y}(t)-p\_fwd)$
#
# $E_{(y\_prev,y)} = E_{(y\_prev,y)}+exp(\alpha_{y}(t)+\beta_{y}(t)+transition(y\_prev,y)+emission(x,y)-p\_fwd)$
#
# $E_{(y,STOP)} =exp(\alpha_{y}(t)+transition(y\_prev,y)-p\_fwd)$
